# %% [markdown]
# # Analysis of time series

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

print('N = ', N, 'L = ', L)

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

# convert y to an (N x n_class) matrix
y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.
# Out:
# N =  10000 L =  60
# data:  10000

# %% [markdown]
# ### Rescale data, split train/val.

# %%
# remove average value of each sample from its values
xm = x.mean(axis=1)
x = (x.T - xm.T).T


# rescale 
x = x/400
# x = x/np.std(x) # if axis is not specified it computes the standard deviation of the flattened array
    
Show_data(x,L,"rescaled data")

perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1)
# Out:
# N_train= 8000   N_val= 2000   L= 60   n_class= 3

# %% [markdown]
# Remove the tilt in the series. It can be useful as it is not related to our problem.

# %%
from scipy import signal
x_detrended = signal.detrend(x)

Show_data(x_detrended, L, 'Detrended series', 8, show=False)
ax = plt.gca()
ax.axhline(0, c="gray", linestyle='--', linewidth=1)
low, high = plt.ylim()
bound = bound = max(abs(low), abs(high))
ax.set_ylim(-bound, bound)

plt.show()

# %% [markdown]
# ## Convolutional NN

# %%
# ... LESSON ...
# reproducibility

import tensorflow.random as tf_r
tf_r.set_seed(12345)

np.random.seed(12345)

from keras import regularizers, initializers
reg = regularizers.l2(0.02)# ridge with lambda
#reg regularizerts.l1(0.1)
ini = keras.initializers.RandomNormal(mean=0., stddev=.05, seed=None)

NCONV = 1
NF = 5 # number of filters

model = Sequential()
if NCONV == 1:
    #-----2----
    model.add(Conv1D(filters=NF, kernel_size=11, kernel_initializer=ini,
                     kernel_regularizer=reg, activation = 'relu', 
                     input_shape=input_shape))
    
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7,
                     activation='relu'))
    model.add(Flatten())# To be sent to a normal neural network layer
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
    



model.add(Dense(n_class, activation='softmax'))
print("-----Model ", NCONV, "------")
model.summary()

#optimizers
#.RMSprop()
#.Nadam()
opt= tf.keras.optimizers.Adam()

#compile the model
#categorical cross entropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
                optimizer=opt, metrics=['accuracy'])
# Out:
# -----Model  1 ------
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 50, 5)             60
#
#  average_pooling1d (AverageP  (None, 10, 5)            0
#  ooling1D)
#
#  conv1d_1 (Conv1D)           (None, 4, 5)              180
#
#  flatten (Flatten)           (None, 20)                0
#
#  dense (Dense)               (None, 12)                252
#
#  dropout (Dropout)           (None, 12)                0
#
#  dense_1 (Dense)             (None, 3)                 39
#
# =================================================================
# Total params: 531
# Trainable params: 531
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers
# Out:
# [<keras.layers.convolutional.Conv1D at 0x7ffad4db57f0>,
#  <keras.layers.pooling.AveragePooling1D at 0x7ffad4dc4fa0>,
#  <keras.layers.convolutional.Conv1D at 0x7ffad4dc4f40>,
#  <keras.layers.core.flatten.Flatten at 0x7ffad42bbca0>,
#  <keras.layers.core.dense.Dense at 0x7ffad4275d60>,
#  <keras.layers.core.dropout.Dropout at 0x7ffad427aca0>,
#  <keras.layers.core.dense.Dense at 0x7ffad4db5b50>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0]#weights
    wT=w.T
    M=len(wT)
    b = model.layers[l].get_weights()[1]#bias
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...

BATCH_SIZE = 250
EPOCHS = 100


print('-------Model',NCONV, '--------\nFITTING,......')
fit = model.fit(x_train, y_train, batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val,y_val),
                verbose=2, shuffle=True)
# Out:
# -------Model 1 --------
# FITTING,......
# Epoch 1/100
# 32/32 - 1s - loss: 1.0994 - accuracy: 0.3483 - val_loss: 1.0951 - val_accuracy: 0.3835 - 974ms/epoch - 30ms/step
# Epoch 2/100
# 32/32 - 0s - loss: 1.0874 - accuracy: 0.4009 - val_loss: 1.0735 - val_accuracy: 0.4205 - 177ms/epoch - 6ms/step
# Epoch 3/100
# 32/32 - 0s - loss: 1.0498 - accuracy: 0.4793 - val_loss: 1.0219 - val_accuracy: 0.5340 - 222ms/epoch - 7ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 0.9823 - accuracy: 0.5732 - val_loss: 0.9340 - val_accuracy: 0.6550 - 180ms/epoch - 6ms/step
# Epoch 5/100
# 32/32 - 0s - loss: 0.9012 - accuracy: 0.6339 - val_loss: 0.8322 - val_accuracy: 0.7080 - 220ms/epoch - 7ms/step
# Epoch 6/100
# 32/32 - 0s - loss: 0.7973 - accuracy: 0.6976 - val_loss: 0.7260 - val_accuracy: 0.7650 - 203ms/epoch - 6ms/step
# Epoch 7/100
# 32/32 - 0s - loss: 0.7027 - accuracy: 0.7449 - val_loss: 0.6204 - val_accuracy: 0.8070 - 197ms/epoch - 6ms/step
# Epoch 8/100
# 32/32 - 0s - loss: 0.6108 - accuracy: 0.7793 - val_loss: 0.5254 - val_accuracy: 0.8450 - 202ms/epoch - 6ms/step
# Epoch 9/100
# 32/32 - 0s - loss: 0.5275 - accuracy: 0.8244 - val_loss: 0.4488 - val_accuracy: 0.8710 - 198ms/epoch - 6ms/step
# Epoch 10/100
# 32/32 - 0s - loss: 0.4661 - accuracy: 0.8539 - val_loss: 0.3858 - val_accuracy: 0.8915 - 202ms/epoch - 6ms/step
# Epoch 11/100
# 32/32 - 0s - loss: 0.4142 - accuracy: 0.8755 - val_loss: 0.3415 - val_accuracy: 0.9025 - 198ms/epoch - 6ms/step
# Epoch 12/100
# 32/32 - 0s - loss: 0.3809 - accuracy: 0.8840 - val_loss: 0.3159 - val_accuracy: 0.9105 - 198ms/epoch - 6ms/step
# Epoch 13/100
# 32/32 - 0s - loss: 0.3508 - accuracy: 0.8946 - val_loss: 0.2892 - val_accuracy: 0.9160 - 206ms/epoch - 6ms/step
# Epoch 14/100
# 32/32 - 0s - loss: 0.3226 - accuracy: 0.9061 - val_loss: 0.2652 - val_accuracy: 0.9280 - 199ms/epoch - 6ms/step
# Epoch 15/100
# 32/32 - 0s - loss: 0.3046 - accuracy: 0.9144 - val_loss: 0.2505 - val_accuracy: 0.9315 - 200ms/epoch - 6ms/step
# Epoch 16/100
# 32/32 - 0s - loss: 0.2889 - accuracy: 0.9169 - val_loss: 0.2382 - val_accuracy: 0.9350 - 197ms/epoch - 6ms/step
# Epoch 17/100
# 32/32 - 0s - loss: 0.2785 - accuracy: 0.9222 - val_loss: 0.2244 - val_accuracy: 0.9380 - 205ms/epoch - 6ms/step
# Epoch 18/100
# 32/32 - 0s - loss: 0.2640 - accuracy: 0.9260 - val_loss: 0.2146 - val_accuracy: 0.9400 - 202ms/epoch - 6ms/step
# Epoch 19/100
# 32/32 - 0s - loss: 0.2493 - accuracy: 0.9319 - val_loss: 0.2069 - val_accuracy: 0.9420 - 197ms/epoch - 6ms/step
# Epoch 20/100
# 32/32 - 0s - loss: 0.2403 - accuracy: 0.9326 - val_loss: 0.1977 - val_accuracy: 0.9455 - 217ms/epoch - 7ms/step
# Epoch 21/100
# 32/32 - 0s - loss: 0.2355 - accuracy: 0.9361 - val_loss: 0.1899 - val_accuracy: 0.9495 - 179ms/epoch - 6ms/step
# Epoch 22/100
# 32/32 - 0s - loss: 0.2247 - accuracy: 0.9392 - val_loss: 0.1835 - val_accuracy: 0.9510 - 199ms/epoch - 6ms/step
# Epoch 23/100
# 32/32 - 0s - loss: 0.2205 - accuracy: 0.9408 - val_loss: 0.1838 - val_accuracy: 0.9545 - 195ms/epoch - 6ms/step
# Epoch 24/100
# 32/32 - 0s - loss: 0.2136 - accuracy: 0.9430 - val_loss: 0.1738 - val_accuracy: 0.9525 - 194ms/epoch - 6ms/step
# Epoch 25/100
# 32/32 - 0s - loss: 0.2033 - accuracy: 0.9494 - val_loss: 0.1718 - val_accuracy: 0.9525 - 197ms/epoch - 6ms/step
# Epoch 26/100
# 32/32 - 0s - loss: 0.1997 - accuracy: 0.9504 - val_loss: 0.1643 - val_accuracy: 0.9570 - 189ms/epoch - 6ms/step
# Epoch 27/100
# 32/32 - 0s - loss: 0.1983 - accuracy: 0.9491 - val_loss: 0.1628 - val_accuracy: 0.9585 - 204ms/epoch - 6ms/step
# Epoch 28/100
# 32/32 - 0s - loss: 0.1901 - accuracy: 0.9535 - val_loss: 0.1608 - val_accuracy: 0.9570 - 192ms/epoch - 6ms/step
# Epoch 29/100
# 32/32 - 0s - loss: 0.1872 - accuracy: 0.9516 - val_loss: 0.1543 - val_accuracy: 0.9615 - 201ms/epoch - 6ms/step
# Epoch 30/100
# 32/32 - 0s - loss: 0.1791 - accuracy: 0.9520 - val_loss: 0.1535 - val_accuracy: 0.9605 - 196ms/epoch - 6ms/step
# Epoch 31/100
# 32/32 - 0s - loss: 0.1759 - accuracy: 0.9549 - val_loss: 0.1467 - val_accuracy: 0.9620 - 196ms/epoch - 6ms/step
# Epoch 32/100
# 32/32 - 0s - loss: 0.1732 - accuracy: 0.9566 - val_loss: 0.1450 - val_accuracy: 0.9615 - 196ms/epoch - 6ms/step
# Epoch 33/100
# 32/32 - 0s - loss: 0.1682 - accuracy: 0.9567 - val_loss: 0.1412 - val_accuracy: 0.9615 - 200ms/epoch - 6ms/step
# Epoch 34/100
# 32/32 - 0s - loss: 0.1672 - accuracy: 0.9595 - val_loss: 0.1386 - val_accuracy: 0.9630 - 195ms/epoch - 6ms/step
# Epoch 35/100
# 32/32 - 0s - loss: 0.1618 - accuracy: 0.9609 - val_loss: 0.1395 - val_accuracy: 0.9620 - 197ms/epoch - 6ms/step
# Epoch 36/100
# 32/32 - 0s - loss: 0.1611 - accuracy: 0.9628 - val_loss: 0.1362 - val_accuracy: 0.9620 - 195ms/epoch - 6ms/step
# Epoch 37/100
# 32/32 - 0s - loss: 0.1557 - accuracy: 0.9624 - val_loss: 0.1336 - val_accuracy: 0.9660 - 198ms/epoch - 6ms/step
# Epoch 38/100
# 32/32 - 0s - loss: 0.1576 - accuracy: 0.9617 - val_loss: 0.1305 - val_accuracy: 0.9640 - 194ms/epoch - 6ms/step
# Epoch 39/100
# 32/32 - 0s - loss: 0.1489 - accuracy: 0.9659 - val_loss: 0.1282 - val_accuracy: 0.9660 - 202ms/epoch - 6ms/step
# Epoch 40/100
# 32/32 - 0s - loss: 0.1499 - accuracy: 0.9650 - val_loss: 0.1278 - val_accuracy: 0.9665 - 196ms/epoch - 6ms/step
# Epoch 41/100
# 32/32 - 0s - loss: 0.1492 - accuracy: 0.9665 - val_loss: 0.1258 - val_accuracy: 0.9655 - 199ms/epoch - 6ms/step
# Epoch 42/100
# 32/32 - 0s - loss: 0.1456 - accuracy: 0.9641 - val_loss: 0.1242 - val_accuracy: 0.9685 - 198ms/epoch - 6ms/step
# Epoch 43/100
# 32/32 - 0s - loss: 0.1410 - accuracy: 0.9674 - val_loss: 0.1211 - val_accuracy: 0.9685 - 197ms/epoch - 6ms/step
# Epoch 44/100
# 32/32 - 0s - loss: 0.1434 - accuracy: 0.9653 - val_loss: 0.1233 - val_accuracy: 0.9680 - 197ms/epoch - 6ms/step
# Epoch 45/100
# 32/32 - 0s - loss: 0.1403 - accuracy: 0.9686 - val_loss: 0.1246 - val_accuracy: 0.9670 - 197ms/epoch - 6ms/step
# Epoch 46/100
# 32/32 - 0s - loss: 0.1429 - accuracy: 0.9666 - val_loss: 0.1190 - val_accuracy: 0.9685 - 195ms/epoch - 6ms/step
# Epoch 47/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6abb7529f8a6> in <cell line: 8>()
#       6
#       7 print('-------Model',NCONV, '--------\nFITTING,......')
# ----> 8 fit = model.fit(x_train, y_train, batch_size=BATCH_SIZE,
#       9                 epochs=EPOCHS,
#      10                 validation_data=(x_val,y_val),
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     907         _tf_function_counter.get_cell(str(int(compiled))).increase_by(1)
#     908
# --> 909     tracing_count = self.experimental_get_tracing_count()
#     910     with trace.Trace(self._name) as tm:
#     911       # TODO(cheshire): Do not duplicate the XLAControlFlowContext annotation.
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in experimental_get_tracing_count(self)
#     878     """
#     879     result = self._stateless_fn.tracing_count if self._stateless_fn else 0
# --> 880     result += self._stateful_fn.tracing_count if self._stateful_fn else 0
#     881     return result
#     882
#
# KeyboardInterrupt:

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
reg2 = regularizers.l2(2.0)
model2 = keras.models.clone_model(model)

model2.layers[0].kernel_regularizer= reg2
model2.layers[2].kernel_regularizer = reg2
model2.compile(loss=keras.losses.categorical_crossentropy, optimizer=opt, metrics=['accuracy'])

BATCH_SIZE2 = 250
EPOCHS2 = 100


fit2 = model2.fit(x_train,y_train, batch_size=BATCH_SIZE2, epochs=EPOCHS2,
                  validation_data=(x_val,y_val),
                  verbose=2, shuffle=True)
# Out:
# Epoch 1/100
# 32/32 - 1s - loss: 1.0324 - accuracy: 0.4456 - val_loss: 0.8909 - val_accuracy: 0.6490 - 735ms/epoch - 23ms/step
# Epoch 2/100
# 32/32 - 0s - loss: 0.7768 - accuracy: 0.7076 - val_loss: 0.6097 - val_accuracy: 0.8200 - 196ms/epoch - 6ms/step
# Epoch 3/100
# 32/32 - 0s - loss: 0.5398 - accuracy: 0.8169 - val_loss: 0.3964 - val_accuracy: 0.8820 - 201ms/epoch - 6ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 0.4030 - accuracy: 0.8731 - val_loss: 0.3121 - val_accuracy: 0.9135 - 204ms/epoch - 6ms/step
# Epoch 5/100
# 32/32 - 0s - loss: 0.3336 - accuracy: 0.9014 - val_loss: 0.2675 - val_accuracy: 0.9240 - 199ms/epoch - 6ms/step
# Epoch 6/100
# 32/32 - 0s - loss: 0.2982 - accuracy: 0.9125 - val_loss: 0.2359 - val_accuracy: 0.9290 - 198ms/epoch - 6ms/step
# Epoch 7/100
# 32/32 - 0s - loss: 0.2680 - accuracy: 0.9234 - val_loss: 0.2198 - val_accuracy: 0.9400 - 196ms/epoch - 6ms/step
# Epoch 8/100
# 32/32 - 0s - loss: 0.2548 - accuracy: 0.9270 - val_loss: 0.2036 - val_accuracy: 0.9450 - 195ms/epoch - 6ms/step
# Epoch 9/100
# 32/32 - 0s - loss: 0.2401 - accuracy: 0.9361 - val_loss: 0.1985 - val_accuracy: 0.9470 - 198ms/epoch - 6ms/step
# Epoch 10/100
# 32/32 - 0s - loss: 0.2301 - accuracy: 0.9377 - val_loss: 0.1854 - val_accuracy: 0.9525 - 225ms/epoch - 7ms/step
# Epoch 11/100
# 32/32 - 0s - loss: 0.2185 - accuracy: 0.9434 - val_loss: 0.1771 - val_accuracy: 0.9585 - 184ms/epoch - 6ms/step
# Epoch 12/100
# 32/32 - 0s - loss: 0.2047 - accuracy: 0.9488 - val_loss: 0.1714 - val_accuracy: 0.9580 - 205ms/epoch - 6ms/step
# Epoch 13/100
# 32/32 - 0s - loss: 0.2019 - accuracy: 0.9485 - val_loss: 0.1663 - val_accuracy: 0.9590 - 193ms/epoch - 6ms/step
# Epoch 14/100
# 32/32 - 0s - loss: 0.1950 - accuracy: 0.9503 - val_loss: 0.1637 - val_accuracy: 0.9585 - 199ms/epoch - 6ms/step
# Epoch 15/100
# 32/32 - 0s - loss: 0.1908 - accuracy: 0.9524 - val_loss: 0.1558 - val_accuracy: 0.9625 - 194ms/epoch - 6ms/step
# Epoch 16/100
# 32/32 - 0s - loss: 0.1819 - accuracy: 0.9539 - val_loss: 0.1526 - val_accuracy: 0.9630 - 207ms/epoch - 6ms/step
# Epoch 17/100
# 32/32 - 0s - loss: 0.1814 - accuracy: 0.9549 - val_loss: 0.1480 - val_accuracy: 0.9640 - 205ms/epoch - 6ms/step
# Epoch 18/100
# 32/32 - 0s - loss: 0.1766 - accuracy: 0.9553 - val_loss: 0.1466 - val_accuracy: 0.9640 - 182ms/epoch - 6ms/step
# Epoch 19/100
# 32/32 - 0s - loss: 0.1711 - accuracy: 0.9591 - val_loss: 0.1427 - val_accuracy: 0.9670 - 198ms/epoch - 6ms/step
# Epoch 20/100
# 32/32 - 0s - loss: 0.1673 - accuracy: 0.9594 - val_loss: 0.1412 - val_accuracy: 0.9645 - 196ms/epoch - 6ms/step
# Epoch 21/100
# 32/32 - 0s - loss: 0.1624 - accuracy: 0.9594 - val_loss: 0.1370 - val_accuracy: 0.9680 - 197ms/epoch - 6ms/step
# Epoch 22/100
# 32/32 - 0s - loss: 0.1615 - accuracy: 0.9603 - val_loss: 0.1362 - val_accuracy: 0.9670 - 196ms/epoch - 6ms/step
# Epoch 23/100
# 32/32 - 0s - loss: 0.1567 - accuracy: 0.9620 - val_loss: 0.1330 - val_accuracy: 0.9685 - 198ms/epoch - 6ms/step
# Epoch 24/100
# 32/32 - 0s - loss: 0.1528 - accuracy: 0.9622 - val_loss: 0.1300 - val_accuracy: 0.9675 - 197ms/epoch - 6ms/step
# Epoch 25/100
# 32/32 - 0s - loss: 0.1501 - accuracy: 0.9645 - val_loss: 0.1294 - val_accuracy: 0.9685 - 197ms/epoch - 6ms/step
# Epoch 26/100
# 32/32 - 0s - loss: 0.1495 - accuracy: 0.9638 - val_loss: 0.1268 - val_accuracy: 0.9690 - 197ms/epoch - 6ms/step
# Epoch 27/100
# 32/32 - 0s - loss: 0.1452 - accuracy: 0.9665 - val_loss: 0.1255 - val_accuracy: 0.9715 - 199ms/epoch - 6ms/step
# Epoch 28/100
# 32/32 - 0s - loss: 0.1454 - accuracy: 0.9674 - val_loss: 0.1240 - val_accuracy: 0.9695 - 199ms/epoch - 6ms/step
# Epoch 29/100
# 32/32 - 0s - loss: 0.1397 - accuracy: 0.9682 - val_loss: 0.1216 - val_accuracy: 0.9710 - 197ms/epoch - 6ms/step
# Epoch 30/100
# 32/32 - 0s - loss: 0.1374 - accuracy: 0.9655 - val_loss: 0.1196 - val_accuracy: 0.9700 - 195ms/epoch - 6ms/step
# Epoch 31/100
# 32/32 - 0s - loss: 0.1375 - accuracy: 0.9660 - val_loss: 0.1190 - val_accuracy: 0.9720 - 198ms/epoch - 6ms/step
# Epoch 32/100
# 32/32 - 0s - loss: 0.1352 - accuracy: 0.9660 - val_loss: 0.1191 - val_accuracy: 0.9690 - 203ms/epoch - 6ms/step
# Epoch 33/100
# 32/32 - 0s - loss: 0.1324 - accuracy: 0.9679 - val_loss: 0.1158 - val_accuracy: 0.9725 - 198ms/epoch - 6ms/step
# Epoch 34/100
# 32/32 - 0s - loss: 0.1291 - accuracy: 0.9689 - val_loss: 0.1154 - val_accuracy: 0.9710 - 198ms/epoch - 6ms/step
# Epoch 35/100
# 32/32 - 0s - loss: 0.1293 - accuracy: 0.9691 - val_loss: 0.1133 - val_accuracy: 0.9725 - 197ms/epoch - 6ms/step
# Epoch 36/100
# 32/32 - 0s - loss: 0.1298 - accuracy: 0.9691 - val_loss: 0.1148 - val_accuracy: 0.9705 - 198ms/epoch - 6ms/step
# Epoch 37/100
# 32/32 - 0s - loss: 0.1248 - accuracy: 0.9703 - val_loss: 0.1121 - val_accuracy: 0.9715 - 196ms/epoch - 6ms/step
# Epoch 38/100
# 32/32 - 0s - loss: 0.1256 - accuracy: 0.9711 - val_loss: 0.1109 - val_accuracy: 0.9720 - 198ms/epoch - 6ms/step
# Epoch 39/100
# 32/32 - 0s - loss: 0.1214 - accuracy: 0.9731 - val_loss: 0.1099 - val_accuracy: 0.9710 - 196ms/epoch - 6ms/step
# Epoch 40/100
# 32/32 - 0s - loss: 0.1201 - accuracy: 0.9719 - val_loss: 0.1116 - val_accuracy: 0.9715 - 196ms/epoch - 6ms/step
# Epoch 41/100
# 32/32 - 0s - loss: 0.1212 - accuracy: 0.9746 - val_loss: 0.1110 - val_accuracy: 0.9715 - 196ms/epoch - 6ms/step
# Epoch 42/100
# 32/32 - 0s - loss: 0.1199 - accuracy: 0.9714 - val_loss: 0.1107 - val_accuracy: 0.9705 - 201ms/epoch - 6ms/step
# Epoch 43/100
# 32/32 - 0s - loss: 0.1184 - accuracy: 0.9715 - val_loss: 0.1071 - val_accuracy: 0.9745 - 198ms/epoch - 6ms/step
# Epoch 44/100
# 32/32 - 0s - loss: 0.1145 - accuracy: 0.9737 - val_loss: 0.1092 - val_accuracy: 0.9705 - 207ms/epoch - 6ms/step
# Epoch 45/100
# 32/32 - 0s - loss: 0.1160 - accuracy: 0.9725 - val_loss: 0.1096 - val_accuracy: 0.9695 - 204ms/epoch - 6ms/step
# Epoch 46/100
# 32/32 - 0s - loss: 0.1177 - accuracy: 0.9743 - val_loss: 0.1045 - val_accuracy: 0.9715 - 201ms/epoch - 6ms/step
# Epoch 47/100
# 32/32 - 0s - loss: 0.1140 - accuracy: 0.9741 - val_loss: 0.1030 - val_accuracy: 0.9730 - 201ms/epoch - 6ms/step
# Epoch 48/100
# 32/32 - 0s - loss: 0.1115 - accuracy: 0.9740 - val_loss: 0.1029 - val_accuracy: 0.9710 - 199ms/epoch - 6ms/step
# Epoch 49/100
# 32/32 - 0s - loss: 0.1112 - accuracy: 0.9753 - val_loss: 0.1021 - val_accuracy: 0.9720 - 199ms/epoch - 6ms/step
# Epoch 50/100
# 32/32 - 0s - loss: 0.1089 - accuracy: 0.9753 - val_loss: 0.1031 - val_accuracy: 0.9725 - 202ms/epoch - 6ms/step
# Epoch 51/100
# 32/32 - 0s - loss: 0.1126 - accuracy: 0.9749 - val_loss: 0.1020 - val_accuracy: 0.9730 - 196ms/epoch - 6ms/step
# Epoch 52/100
# 32/32 - 0s - loss: 0.1071 - accuracy: 0.9760 - val_loss: 0.1004 - val_accuracy: 0.9720 - 202ms/epoch - 6ms/step
# Epoch 53/100
# 32/32 - 0s - loss: 0.1059 - accuracy: 0.9765 - val_loss: 0.1015 - val_accuracy: 0.9710 - 203ms/epoch - 6ms/step
# Epoch 54/100
# 32/32 - 0s - loss: 0.1066 - accuracy: 0.9753 - val_loss: 0.1001 - val_accuracy: 0.9720 - 197ms/epoch - 6ms/step
# Epoch 55/100
# 32/32 - 0s - loss: 0.1036 - accuracy: 0.9770 - val_loss: 0.0986 - val_accuracy: 0.9715 - 200ms/epoch - 6ms/step
# Epoch 56/100
# 32/32 - 0s - loss: 0.1036 - accuracy: 0.9774 - val_loss: 0.0985 - val_accuracy: 0.9715 - 201ms/epoch - 6ms/step
# Epoch 57/100
# 32/32 - 0s - loss: 0.1030 - accuracy: 0.9779 - val_loss: 0.0981 - val_accuracy: 0.9730 - 199ms/epoch - 6ms/step
# Epoch 58/100
# 32/32 - 0s - loss: 0.0990 - accuracy: 0.9784 - val_loss: 0.0977 - val_accuracy: 0.9740 - 203ms/epoch - 6ms/step
# Epoch 59/100
# 32/32 - 0s - loss: 0.0999 - accuracy: 0.9785 - val_loss: 0.0959 - val_accuracy: 0.9720 - 197ms/epoch - 6ms/step
# Epoch 60/100
# 32/32 - 0s - loss: 0.0989 - accuracy: 0.9786 - val_loss: 0.0953 - val_accuracy: 0.9730 - 221ms/epoch - 7ms/step
# Epoch 61/100
# 32/32 - 0s - loss: 0.1010 - accuracy: 0.9787 - val_loss: 0.0948 - val_accuracy: 0.9730 - 197ms/epoch - 6ms/step
# Epoch 62/100
# 32/32 - 0s - loss: 0.1025 - accuracy: 0.9774 - val_loss: 0.0960 - val_accuracy: 0.9755 - 176ms/epoch - 6ms/step
# Epoch 63/100
# 32/32 - 0s - loss: 0.0983 - accuracy: 0.9779 - val_loss: 0.0934 - val_accuracy: 0.9750 - 220ms/epoch - 7ms/step
# Epoch 64/100
# 32/32 - 0s - loss: 0.0965 - accuracy: 0.9797 - val_loss: 0.0932 - val_accuracy: 0.9735 - 177ms/epoch - 6ms/step
# Epoch 65/100
# 32/32 - 0s - loss: 0.0980 - accuracy: 0.9776 - val_loss: 0.0923 - val_accuracy: 0.9740 - 196ms/epoch - 6ms/step
# Epoch 66/100
# 32/32 - 0s - loss: 0.0970 - accuracy: 0.9781 - val_loss: 0.0936 - val_accuracy: 0.9740 - 196ms/epoch - 6ms/step
# Epoch 67/100
# 32/32 - 0s - loss: 0.0966 - accuracy: 0.9786 - val_loss: 0.0916 - val_accuracy: 0.9765 - 205ms/epoch - 6ms/step
# Epoch 68/100
# 32/32 - 0s - loss: 0.0927 - accuracy: 0.9801 - val_loss: 0.0903 - val_accuracy: 0.9755 - 197ms/epoch - 6ms/step
# Epoch 69/100
# 32/32 - 0s - loss: 0.0939 - accuracy: 0.9796 - val_loss: 0.0906 - val_accuracy: 0.9760 - 196ms/epoch - 6ms/step
# Epoch 70/100
# 32/32 - 0s - loss: 0.0913 - accuracy: 0.9783 - val_loss: 0.0895 - val_accuracy: 0.9770 - 197ms/epoch - 6ms/step
# Epoch 71/100
# 32/32 - 0s - loss: 0.0928 - accuracy: 0.9790 - val_loss: 0.0891 - val_accuracy: 0.9765 - 198ms/epoch - 6ms/step
# Epoch 72/100
# 32/32 - 0s - loss: 0.0917 - accuracy: 0.9806 - val_loss: 0.0894 - val_accuracy: 0.9745 - 221ms/epoch - 7ms/step
# Epoch 73/100
# 32/32 - 0s - loss: 0.0931 - accuracy: 0.9795 - val_loss: 0.0899 - val_accuracy: 0.9750 - 200ms/epoch - 6ms/step
# Epoch 74/100
# 32/32 - 0s - loss: 0.0905 - accuracy: 0.9786 - val_loss: 0.0871 - val_accuracy: 0.9755 - 200ms/epoch - 6ms/step
# Epoch 75/100
# 32/32 - 0s - loss: 0.0898 - accuracy: 0.9806 - val_loss: 0.0876 - val_accuracy: 0.9770 - 195ms/epoch - 6ms/step
# Epoch 76/100
# 32/32 - 0s - loss: 0.0922 - accuracy: 0.9784 - val_loss: 0.0869 - val_accuracy: 0.9775 - 176ms/epoch - 6ms/step
# Epoch 77/100
# 32/32 - 0s - loss: 0.0896 - accuracy: 0.9790 - val_loss: 0.0870 - val_accuracy: 0.9765 - 199ms/epoch - 6ms/step
# Epoch 78/100
# 32/32 - 0s - loss: 0.0928 - accuracy: 0.9769 - val_loss: 0.0865 - val_accuracy: 0.9780 - 245ms/epoch - 8ms/step
# Epoch 79/100
# 32/32 - 0s - loss: 0.0904 - accuracy: 0.9779 - val_loss: 0.0857 - val_accuracy: 0.9755 - 308ms/epoch - 10ms/step
# Epoch 80/100
# 32/32 - 0s - loss: 0.0882 - accuracy: 0.9811 - val_loss: 0.0868 - val_accuracy: 0.9770 - 197ms/epoch - 6ms/step
# Epoch 81/100
# 32/32 - 0s - loss: 0.0851 - accuracy: 0.9818 - val_loss: 0.0840 - val_accuracy: 0.9785 - 216ms/epoch - 7ms/step
# Epoch 82/100
# 32/32 - 0s - loss: 0.0880 - accuracy: 0.9780 - val_loss: 0.0851 - val_accuracy: 0.9765 - 196ms/epoch - 6ms/step
# Epoch 83/100
# 32/32 - 0s - loss: 0.0843 - accuracy: 0.9810 - val_loss: 0.0851 - val_accuracy: 0.9760 - 204ms/epoch - 6ms/step
# Epoch 84/100
# 32/32 - 0s - loss: 0.0845 - accuracy: 0.9801 - val_loss: 0.0843 - val_accuracy: 0.9775 - 195ms/epoch - 6ms/step
# Epoch 85/100
# 32/32 - 0s - loss: 0.0836 - accuracy: 0.9810 - val_loss: 0.0867 - val_accuracy: 0.9775 - 196ms/epoch - 6ms/step
# Epoch 86/100
# 32/32 - 0s - loss: 0.0878 - accuracy: 0.9799 - val_loss: 0.0826 - val_accuracy: 0.9790 - 217ms/epoch - 7ms/step
# Epoch 87/100
# 32/32 - 0s - loss: 0.0826 - accuracy: 0.9821 - val_loss: 0.0824 - val_accuracy: 0.9770 - 194ms/epoch - 6ms/step
# Epoch 88/100
# 32/32 - 0s - loss: 0.0836 - accuracy: 0.9809 - val_loss: 0.0842 - val_accuracy: 0.9755 - 196ms/epoch - 6ms/step
# Epoch 89/100
# 32/32 - 0s - loss: 0.0834 - accuracy: 0.9809 - val_loss: 0.0814 - val_accuracy: 0.9770 - 195ms/epoch - 6ms/step
# Epoch 90/100
# 32/32 - 0s - loss: 0.0808 - accuracy: 0.9815 - val_loss: 0.0819 - val_accuracy: 0.9785 - 199ms/epoch - 6ms/step
# Epoch 91/100
# 32/32 - 0s - loss: 0.0818 - accuracy: 0.9795 - val_loss: 0.0835 - val_accuracy: 0.9775 - 202ms/epoch - 6ms/step
# Epoch 92/100
# 32/32 - 0s - loss: 0.0828 - accuracy: 0.9809 - val_loss: 0.0797 - val_accuracy: 0.9780 - 191ms/epoch - 6ms/step
# Epoch 93/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f389568f9822> in <cell line: 13>()
#      11
#      12
# ---> 13 fit2 = model2.fit(x_train,y_train, batch_size=BATCH_SIZE2, epochs=EPOCHS2,
#      14                   validation_data=(x_val,y_val),
#      15                   verbose=2, shuffle=True)
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1418                 model=self,
#    1419                 steps_per_execution=self._steps_per_execution)
# -> 1420           val_logs = self.evaluate(
#    1421               x=val_x,
#    1422               y=val_y,
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1708       self._test_counter.assign(0)
#    1709       callbacks.on_test_begin()
# -> 1710       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1711         self.reset_metrics()
#    1712         with data_handler.catch_stop_iteration():
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1189     """Yields `(epoch, tf.data.Iterator)`."""
#    1190     with self._truncate_execution_to_epoch():
# -> 1191       data_iterator = iter(self._dataset)
#    1192       for epoch in range(self._initial_epoch, self._epochs):
#    1193         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     753             "When `dataset` is provided, `element_spec` and `components` must "
#     754             "not be specified.")
# --> 755       self._create_iterator(dataset)
#     756
#     757     self._get_next_call_count = 0
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     785                 output_types=self._flat_output_types,
#     786                 output_shapes=self._flat_output_shapes))
# --> 787         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788         # Delete the resource when this object is deleted
#     789         self._resource_deleter = IteratorResourceDeleter(
#
# /shared-libs/python3.8/py/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3313   if tld.is_eager:
#    3314     try:
# -> 3315       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3316         _ctx, "MakeIterator", name, dataset, iterator)
#    3317       return _result
#
# KeyboardInterrupt:

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")

# %%
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"]
cmap="GnBu"

def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)

#print(classification_report(max_y_val, max_y_pred_val))

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3c8e8699-579b-4f24-9413-a98afebf04a2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
